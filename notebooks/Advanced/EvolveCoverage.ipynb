# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/ArtificialIntelligenceToolkit/aitk/blob/master/notebooks/Advanced/EvolveCoverage.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import math
from pathlib import Path

# %pip install -q svgwrite ipywidgets
# !brew install graphviz

repo_root = Path.cwd().resolve()
while repo_root != repo_root.parent and not (repo_root / "aitk" / "robots" / "world.py").exists():
    repo_root = repo_root.parent

sys.path.insert(0, str(repo_root))
sys.path.insert(0, str(repo_root / "aitk" / "algorithms"))

for name in list(sys.modules):
    if (
        name == "aitk"
        or name.startswith("aitk.")
        or name == "neat"
        or name.startswith("neat.")
    ):
        del sys.modules[name]

import aitk.robots
import aitk.utils
from aitk.robots.world import World
from aitk.utils import Grid
import ipywidgets as widgets
import neat

widgets.IntSlider()
print("Using aitk from:", aitk.__file__)
print("Using neat from:", neat.__file__)
# Out:
# [notice] A new release of pip is available: 24.1.2 -> 26.0.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# zsh:1: command not found: brew
# Using aitk from: /Users/reishirokawakami/Desktop/Projects/aitk_soccer_experiments/aitk/__init__.py
# Using neat from: /Users/reishirokawakami/Desktop/Projects/aitk_soccer_experiments/aitk/algorithms/neat/__init__.py

# %% [markdown]
# ## Evolving coverage
#
# This program uses NEAT to evolve a neural network robot controller
# with a fitness function that maximizes coverage of the environment.
# It uses a Grid imposed on the World to track the robot's location
# over time. It uses the percentage of grid positions visited as
# a fitness function.

# %%
world = aitk.robots.World(width=200, height=200, scale=5.0, quiet=True)
robot = aitk.robots.Scribbler(x=100, y=100, a=87, max_trace_length=60)
robot.add_device(aitk.robots.RangeSensor(position=(6,0),max=100,a=0,width=0,name="laser"))
robot.add_device(aitk.robots.RangeSensor(position=(6,-6),max=20,a=0,width=57.3,name="left-ir"))
robot.add_device(aitk.robots.RangeSensor(position=(6,6),max=20,a=0,width=57.3,name="right-ir"))
world.add_robot(robot)
world.update()
world.save()

# %%
world.watch(width=500)
# Out:
# Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x0…

# %% [markdown]
# ## Sensor inputs for achieving coverage
#
# What are the best sensors for allowing NEAT to find good coverage solutions? Here are some options to consider:
#
# * all or some subset of the scaled range sensors (irs and laser)
#    * You may want to use 1 - scaled_value
# * whether the robot is stalled
# * scaled timer (gives a sense of how long a trial will last)
#   * A count down timer starts at 1.0 and decreases linearly to 0.0.
#   * A count up timer works in the reverse direction. It starts at 0.0 and increases linearly to 1.0.
# * bias (some constant value)
# * current coverage
#
# Whatever sensors you choose to use you must ensure that the converage.config file is set for the appropriate number of input values.
#
# Remember that all inputs and targets to a neural network should be scaled to match the range of the activation function. In our case, this will be tanh which has a range of [-1,1]. The range of this function allows the network's two outputs, which represent the robot's translation and rotation on each step to be both forward/backward and left/right.

# %%
def get_sensors(robot, max_time):
    """Currently uses 6 sensors"""
    Lir = 1.0 - robot["left-ir"].get_distance()/robot["left-ir"].get_max()
    Rir = 1.0 - robot["right-ir"].get_distance()/robot["right-ir"].get_max()
    laser = 1.0 - robot["laser"].get_distance()/robot["laser"].get_max()
    timer = 1 - robot.world.time/max_time
    stall = 0
    bias = 1.0
    if robot.stalled:
        stall = 1
    return [timer, Lir, Rir, laser, stall, bias]

# %% [markdown]
# ## Evaluate fitness for each individual
#
# Feed the robot's current sensor values as input to the neural network and use the output that's produced as the action to take (representing translate and rotate amounts).

# %%
def neat_controller(robot):
    robot.state["grid"].draw()
    robot.move(robot.state["translate"], robot.state["rotate"])

def eval_fitness(net, max_time, watch=False):
    stall_counter = 0
    robot.world.reset()
    robot.state["grid"] = Grid((10, 10), robot.world)
    robot.state["translate"] = 0
    robot.state["rotate"] = 0
    for i in range(max_time):
        x, y, direction = robot.get_pose()
        if robot.stalled:
            stall_counter += 1
        else:
            stall_counter = 0
        if stall_counter > 10:
            # end evaluation of stalled controllers
            break
        robot.state["grid"].update(x, y)
        sensor_vals = get_sensors(robot, max_time)
        output = net.activate(sensor_vals)
        robot.state["translate"] = output[0]
        robot.state["rotate"] = output[1]
        # Use the same action command for half a second
        world.steps(5,[neat_controller], real_time=False, show=watch, quiet=True)
    return robot.state["grid"].analyze_visits()

# %% [markdown]
# ## Evaluate fitness for the entire population

# %%
def eval_population(pop, config):
    """This function must take these two parameters"""
    for genome_id, genome in pop:
        net = neat.nn.FeedForwardNetwork.create(genome, config)
        genome.fitness = eval_fitness(net, 60, watch=False)

# %% [markdown]
# ## Define how to run the evolutionary process

# %%
def run(config_file):
    # Load configuration
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Create the population, which is the top-level object for a NEAT run.
    p = neat.Population(config)

    # Add a stdout reporter to show progress in the terminal.
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)
    # Uncomment this to save checkpoints every 5 generations
    # p.add_reporter(neat.Checkpointer(5))

    winner = p.run(eval_population, 10)

    # Display the winning genome.
    print('\nBest genome:\n{!s}'.format(winner))
    node_names = {-1:'d1', -2:'d2', -3:'d3', -4:'timer', 
                  -5:'stall', -6:'bias', 
                  0:'translate', 1: 'rotate'}
    # neat.visualize.draw_net(config, winner, True, node_names=node_names)
    # neat.visualize.plot_stats(stats, ylog=False, view=True)
    # neat.visualize.plot_species(stats, view=True)
    
    return winner

# %%
# %%writefile coverage.config
# #--- parameters for the Robot Coverage experiment ---#
#
# [NEAT]
# fitness_criterion     = max
# fitness_threshold     = 0.95
# pop_size              = 50
# reset_on_extinction   = False
#
# [DefaultGenome]
# # node activation options
# activation_default      = tanh
# activation_mutate_rate  = 0.0
# activation_options      = tanh
#
# # node aggregation options
# aggregation_default     = sum
# aggregation_mutate_rate = 0.0
# aggregation_options     = sum
#
# # node bias options
# bias_init_mean          = 0.0
# bias_init_stdev         = 1.0
# bias_max_value          = 30.0
# bias_min_value          = -30.0
# bias_mutate_power       = 0.5
# bias_mutate_rate        = 0.7
# bias_replace_rate       = 0.1
#
# # genome compatibility options
# compatibility_disjoint_coefficient = 1.0
# compatibility_weight_coefficient   = 0.5
#
# # connection add/remove rates
# conn_add_prob           = 0.5
# conn_delete_prob        = 0.5
#
# # connection enable options
# enabled_default         = True
# enabled_mutate_rate     = 0.01
#
# feed_forward            = True
# initial_connection      = full
#
# # node add/remove rates
# node_add_prob           = 0.35
# node_delete_prob        = 0.35
#
# # network parameters
# num_hidden              = 0
# num_inputs              = 6
# num_outputs             = 2
#
# # node response options
# response_init_mean      = 1.0
# response_init_stdev     = 0.0
# response_max_value      = 30.0
# response_min_value      = -30.0
# response_mutate_power   = 0.0
# response_mutate_rate    = 0.0
# response_replace_rate   = 0.0
#
# # connection weight options
# weight_init_mean        = 0.0
# weight_init_stdev       = 1.0
# weight_max_value        = 30
# weight_min_value        = -30
# weight_mutate_power     = 0.5
# weight_mutate_rate      = 0.8
# weight_replace_rate     = 0.1
#
# [DefaultSpeciesSet]
# compatibility_threshold = 2.0
#
# [DefaultStagnation]
# species_fitness_func = max
# max_stagnation       = 20
# species_elitism      = 1
#
# [DefaultReproduction]
# elitism            = 2
# survival_threshold = 0.2
# Out:
# Overwriting coverage.config

# %%
winner = run("coverage.config")
# Out:
#  ****** Running generation 0 ******
#
# Population's average fitness: 0.04420 stdev: 0.02192
# Best fitness: 0.16000 - size: (2, 12) - species 1 - id 4
# Average adjusted fitness: 0.022
# Mean genetic distance 1.334, standard deviation 0.467
# Population of 50 members in 2 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0    38      0.2    0.024     0
#      2    0    12      0.0    0.020     0
# Total extinctions: 0
# Generation time: 3.932 sec
#
#  ****** Running generation 1 ******
#
# Population's average fitness: 0.06320 stdev: 0.05144
# Best fitness: 0.26000 - size: (2, 12) - species 1 - id 82
# Average adjusted fitness: 0.034
# Mean genetic distance 1.378, standard deviation 0.419
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1    19      0.3    0.032     0
#      2    1    23      0.2    0.037     0
#      3    0     8       --       --     0
# Total extinctions: 0
# Generation time: 3.895 sec (3.914 average)
#
#  ****** Running generation 2 ******
#
# Population's average fitness: 0.09500 stdev: 0.07948
# Best fitness: 0.31000 - size: (3, 13) - species 2 - id 99
# Average adjusted fitness: 0.070
# Mean genetic distance 1.432, standard deviation 0.373
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2    24      0.3    0.038     1
#      2    2     9      0.3    0.076     0
#      3    1    17      0.2    0.096     0
# Total extinctions: 0
# Generation time: 3.921 sec (3.916 average)
#
#  ****** Running generation 3 ******
#
# Population's average fitness: 0.09460 stdev: 0.08859
# Best fitness: 0.35000 - size: (3, 13) - species 1 - id 168
# Average adjusted fitness: 0.075
# Mean genetic distance 1.405, standard deviation 0.322
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3     7      0.3    0.095     0
#      2    3    24      0.1    0.031     1
#      3    2    20      0.3    0.099     0
# Total extinctions: 0
# Generation time: 3.902 sec (3.912 average)
#
#  ****** Running generation 4 ******
#
# Population's average fitness: 0.10059 stdev: 0.09211
# Best fitness: 0.35000 - size: (3, 13) - species 2 - id 168
# Average adjusted fitness: 0.086
# Mean genetic distance 1.373, standard deviation 0.333
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4    20      0.2    0.069     1
#      2    4     6      0.3    0.081     0
#      3    3    25      0.3    0.110     0
# Total extinctions: 0
# Generation time: 4.063 sec (3.943 average)
#
#  ****** Running generation 5 ******
#
# Population's average fitness: 0.09647 stdev: 0.08838
# Best fitness: 0.35000 - size: (3, 13) - species 3 - id 168
# Average adjusted fitness: 0.091
# Mean genetic distance 1.278, standard deviation 0.337
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5    21      0.3    0.080     2
#      2    5    14      0.2    0.105     1
#      3    4    16      0.3    0.088     0
# Total extinctions: 0
# Generation time: 4.099 sec (3.969 average)
#
#  ****** Running generation 6 ******
#
# Population's average fitness: 0.09059 stdev: 0.08908
# Best fitness: 0.35000 - size: (3, 13) - species 1 - id 168
# Average adjusted fitness: 0.081
# Mean genetic distance 1.335, standard deviation 0.310
# Population of 49 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6    28      0.3    0.079     3
#      2    6     7      0.3    0.084     2
#      3    5    14      0.3    0.080     1
# Total extinctions: 0
# Generation time: 3.988 sec (3.971 average)
#
#  ****** Running generation 7 ******
#
# Population's average fitness: 0.11102 stdev: 0.10369
# Best fitness: 0.37000 - size: (4, 14) - species 1 - id 360
# Average adjusted fitness: 0.087
# Mean genetic distance 1.464, standard deviation 0.407
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7    21      0.4    0.111     0
#      2    7    11      0.1    0.036     3
#      3    6    18      0.3    0.114     2
# Total extinctions: 0
# Generation time: 3.841 sec (3.955 average)
#
#  ****** Running generation 8 ******
#
# Population's average fitness: 0.08160 stdev: 0.08682
# Best fitness: 0.37000 - size: (4, 14) - species 3 - id 360
# Average adjusted fitness: 0.071
# Mean genetic distance 1.627, standard deviation 0.400
# Population of 51 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8    28      0.3    0.060     1
#      2    8     6      0.1    0.060     4
#      3    7    17      0.4    0.092     0
# Total extinctions: 0
# Generation time: 3.936 sec (3.953 average)
#
#  ****** Running generation 9 ******
#
# Population's average fitness: 0.08157 stdev: 0.09067
# Best fitness: 0.37000 - size: (4, 14) - species 1 - id 360
# Average adjusted fitness: 0.059
# Mean genetic distance 1.678, standard deviation 0.443
# Population of 50 members in 3 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9    29      0.4    0.089     2
#      2    9     7      0.1    0.032     5
#      3    8    14      0.3    0.057     1
# Total extinctions: 0
# Generation time: 4.005 sec (3.958 average)
#
# Best genome:
# Key: 360
# Fitness: 0.37
# Nodes:
# 	0 DefaultNodeGene(key=0, bias=2.1756278248156056, response=1.0, activation=tanh, aggregation=sum)
# 	1 DefaultNodeGene(key=1, bias=-0.39688377939152, response=1.0, activation=tanh, aggregation=sum)
# 	35 DefaultNodeGene(key=35, bias=1.244964491690352, response=1.0, activation=tanh, aggregation=sum)
# 	110 DefaultNodeGene(key=110, bias=-1.0531950207311411, response=1.0, activation=tanh, aggregation=sum)
# Connections:
# 	DefaultConnectionGene(key=(-6, 0), weight=1.2944639716052686, enabled=True)
# 	DefaultConnectionGene(key=(-6, 1), weight=-0.03588888350789987, enabled=True)
# 	DefaultConnectionGene(key=(-5, 0), weight=0.1004638624680414, enabled=True)
# 	DefaultConnectionGene(key=(-5, 1), weight=-0.329677190105288, enabled=True)
# 	DefaultConnectionGene(key=(-4, 0), weight=-0.6529625665668598, enabled=False)
# 	DefaultConnectionGene(key=(-4, 1), weight=0.18055149453698316, enabled=True)
# 	DefaultConnectionGene(key=(-4, 110), weight=1.401214907588541, enabled=True)
# 	DefaultConnectionGene(key=(-3, 0), weight=1.0788713904416913, enabled=True)
# 	DefaultConnectionGene(key=(-3, 1), weight=0.6665590903755343, enabled=True)
# 	DefaultConnectionGene(key=(-2, 0), weight=0.49037300520410954, enabled=False)
# 	DefaultConnectionGene(key=(-2, 1), weight=-0.2508690003130182, enabled=True)
# 	DefaultConnectionGene(key=(-2, 35), weight=0.5663719307866868, enabled=True)
# 	DefaultConnectionGene(key=(-1, 0), weight=-0.10417180692554631, enabled=True)
# 	DefaultConnectionGene(key=(-1, 1), weight=0.5419709746436734, enabled=True)
# 	DefaultConnectionGene(key=(35, 0), weight=0.8725892833017248, enabled=True)
# 	DefaultConnectionGene(key=(110, 0), weight=-0.7291474868227372, enabled=True)

# %%
# Test the winning network
config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         "coverage.config")
winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
eval_fitness(winner_net, 60, watch=True)
# Out:
# 0.37

# %% [markdown]
# During evolution, we only allowed the robot to make 60 moves when evaluating fitness.  What happens when we allow the robot to move twice as many times?

# %%
eval_fitness(winner_net, 120, watch=True)
# Out:
# 0.41

# %% [markdown]
# What if we go three times as long?

# %%
eval_fitness(winner_net, 180, watch=True)
# Out:
# 0.47

# %% [markdown]
# In some evolved solutions, the fitness will increase the longer you allow the robot to move.  This is a nice result, when it happens.  It indicates that evolution has discovered a good, robust solution.
